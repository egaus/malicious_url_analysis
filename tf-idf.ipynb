# %% [markdown]
# # TF-IDF

# %% [markdown]
# A method to identify the importance of a word relative to the entire corpus

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('./data/phishing_dataset.csv')
df['uri'] = df.uri.apply(str)
df[['url', 'label']]
# Out:
#                                                                                                                                                                                                                                                     url  \
# 0      http://stpatricksfc.net/xs/cn/ac38648851b8d41a726d486e13a781eb/?login=&.verify?service=mail&data:text/html;charset=utf-8;base64,PGh0bWw+DQo8c3R5bGU+IGJvZHkgeyBtYXJnaW46IDA7IG92ZXJmbG93OiBoaWRkZW47IH0gPC9zdHlsZT4NCiAgPGlmcmFt
# 1      http://freeemailextractor.us/305bd4c64738af203e5544c86393d9d1
# 2      http://52.70.129.120/js/.wp.php/rf/myaccount/34622/
# 3      http://52.70.129.120/js/.wp.php/rf/myaccount/34622/home?cmd=_account-details&session=626dcf1ea909ba1d031b89440d6ad034&dispatch=0405946fc903c08eb521696f62e245b18eadcfd7
# 4      http://ahaslo.org/ayv/pdf/87b6f0ef86c9a996fe35ef9d27354440/
# 5      http://syshainc.com/OPC/54cd9ed8eabe2f3d7cf4ca1a60f2f362/
# 6      http://syshainc.com/OPC/54cd9ed8eabe2f3d7cf4ca1a60f2f362/pass.php
# 7      http://syshainc.com/OPC/54cd9ed8eabe2f3d7cf4ca1a60f2f362/error.php
# 8      http://mustardtech.com/live/7da8f0dbfabacc817c1caf46a48a6a4c/login2.php?https://login.live.com/public/IdentifyUser.aspx?LOB=RBGLogon
# 9      http://mustardtech.com/live/7da8f0dbfabacc817c1caf46a48a6a4c
# 10     http://mustardtech.com/live/7da8f0dbfabacc817c1caf46a48a6a4c/verify.php?cmd=login_submit&id=36977569f4fbc39b7f99dbd92b601b9c36977569f4fbc39b7f99dbd92b601b9c&session=36977569f4fbc39b7f99dbd92b601b9c36977569f4fbc39b7f99dbd92b601b9c
# 11     http://mustardtech.com/live/7da8f0dbfabacc817c1caf46a48a6a4c/login.php?https://login.live.com/public/IdentifyUser.aspx?LOB=RBGLogon
# 12     http://mustardtech.com/live/7da8f0dbfabacc817c1caf46a48a6a4c/verify.php?cmd=login_submit&id=350c1a296bb6aa138c8e6ad46222409c350c1a296bb6aa138c8e6ad46222409c&session=350c1a296bb6aa138c8e6ad46222409c350c1a296bb6aa138c8e6ad46222409c
# 13     http://www.natwestcustomerlogon.livebetterforever.co.uk/step2.php
# 14     http://www.natwestcustomerlogon.livebetterforever.co.uk/step3.php
# 15     http://www.natwestcustomerlogon.livebetterforever.co.uk/login.php?cmd=login_submit
# 16     http://cspage2018.000webhostapp.com/bayar/VisaPayments.html?count=0
# 17     http://pages-help-share.000webhostapp.com/Restored-Help-Unblock/marks.html?count=0
# 18     http://pages-help-share.000webhostapp.com/Restored-Help-Unblock/VisaPayments.html?fb_source=bookmark_apps&ref=bookmarks&count=0&fb_bmpos=login_failed
# 19     http://pages-help-share.000webhostapp.com/Restored-Help-Unblock/VisaPayments.html?count=0
# 20     http://amazon.de.mailletter10.com/203405/RBbW9RXLY70N/Jdnk0uM7YjqHoarPwe8xmOqFA/
# 21     http://gepc.or.tz/office_Inc/outlook/outlook/authentication.php
# 22     https://www.bitly.im/schV6/
# 23     http://www.storplast.com.ua/administrator/modules/mod_custom/login.php?cmd=login_submit&amp%3Bid=88d314fb1d302946cdc55fdccee02c6b88d314fb1d302946cdc55fdccee02c6b&amp%3Bsession=88d314fb1d302946cdc55fdccee02c6b88d314fb1d302946cdc55fdccee02c6b
# 24     http://www.storplast.com.ua/administrator/modules/mod_custom/step2.php
# 25     http://accessstaff.org/test/.,/Dhl.htm
# 26     http://accessstaff.org/cels/Dhl.htm
# 27     http://thetekunion.com/update/insta/jk/index.htm
# 28     http://buildingcastles.us/smush/login.php
# 29     http://buildingcastles.us/smush/step2.php
# ...                                          ...
# 45250  http://williamjordan.ca/formgen/use/redirect/form1.html
# 45251  http://www.speedplumbing.com/ppsecure/security/verified_by_paypal/webscrcmd=_login-run/cgi-bin/_login/Confirm.php?cmd=_Confirm&dispatch=5885d80a13c0db1fb6947b0aeae66fdbfb2119927117885d80a13c0db1fb6947b0aeae66fdbfb211992e3a6f876e0fd34af4365
# 45252  http://nlservices.com/nala/accounts.paypal/secure.net/webscr.html
# 45253  http://www.creativemindsdesign.com/cgi_bin/www.paypal.de/DE_de/ssl_enc=true/cmd=run_login&get.accid=67854235/#&get=003-051-395-128
# 45254  http://www.creativemindsdesign.com/http/cgi/www.paypal.com/EN_us/ssl_enc=true/cmd=run_login&get.accid=67854235/#&get=003-051-395-128
# 45255  http://www.paypal.com.login.php.lasermachine.in/login.php?errors2=1
# 45256  http://mc2i-technologie.fr/xmlrpc/inde.php??tevreau
# 45257  http://ifpp.org/~justathought/var/paypal.com/fr/webscr.php?cmd=_login-run
# 45258  http://dublinwebdesign.com/~justathought/var/paypal.com/fr/webscr.php?cmd=_login-run
# 45259  http://www.newlifebaptistchurch.com/aol/survey/login.htm?paypal.com/us/cgi-bin/webscr?cmd=_login-submit&amp;dispatch=5885d80a13c0db1f1ff80d546411d7f8a8350c132bc41e0934cfc023d4e8f9e5
# 45260  http://www.paypal.com.aero-group.com/.pay.php
# 45261  http://www.watchesstore.co.uk/paypal.com/paypal.com/webscr.php?cmd=_login-validate&amp;login_access=ea398652eacd641d7d2768fea6c02f91
# 45262  http://revistaenlace.com.br/facebook_com.htm
# 45263  http://www.paypal.com.id451f58f52x48f28ear5c4gf87aze.mmc.x10.mx/webscr.php
# 45264  http://mundovirtualhabbo.blogspot.com/2009_01_01_archive.html
# 45265  http://creditgratosse.blogspot.com/2008/01/connnectoi_03.html
# 45266  http://aijcs.blogspot.com/2005/03/colourful-life-of-aij.html
# 45267  http://www.hellg2.friko.pl/loginsubmit.htm
# 45268  http://tnet.at.ua/index/0-13
# 45269  http://tudu-free.blogspot.com/2008/02/jogos-java-aplicativos.html#footer-wrap2
# 45270  http://www.thai4uk.com/acatalog/www.paypal.com/cgi-bin/webscr/cmd=_login-run/
# 45271  http://uaedesign.com/login/www.paypal.com/paypal/cgi-bin/
# 45272  http://www.wordoftodd.com/wordpress/paypal.com.au/https/cgi-bin/webscrcmd=_login-run/webscrcmd=_account-run/updates-paypal/confirm-paypal/index.htm
# 45273  http://www.ecommercem.com/www.PayPal.Com22/webscrcmd=_login-done&login_access=1190737782.htm
# 45274  http://www.comictube.com/m_hotties/.www.paypal.com/us/cgi-bin/webscr/web_login-update/
# 45275  http://www.paypal.com.serv-5-redirect.aortadobrasil.com/cgi-bin/us/webscr.php?cmd=_login-run
# 45276  http://www.paypal.com.serv-1-redirect.aortadobrasil.com/cgi-bin/us/webscr.php?cmd=_login-run
# 45277  http://www.avgt.com/update.paypal.com/clients/update/cgi-bin/webscr.php?cmd=_login-run
# 45278  http://www.avgt.com/www.paypal.com/clients/update/cgi-bin/webscr.php?cmd=_login-run
# 45279  http://www.floridarentfinders.com/uploads/ws/css/www.paypal.com/cgi-bin/webscrcmd=_login-run/update.php
#
#            label
# 0      malicious
# 1      malicious
# 2      malicious
# 3      malicious
# 4      malicious
# 5      malicious
# 6      malicious
# 7      malicious
# 8      malicious
# 9      malicious
# 10     malicious
# 11     malicious
# 12     malicious
# 13     malicious
# 14     malicious
# 15     malicious
# 16     malicious
# 17     malicious
# 18     malicious
# 19     malicious
# 20     malicious
# 21     malicious
# 22     malicious
# 23     malicious
# 24     malicious
# 25     malicious
# 26     malicious
# 27     malicious
# 28     malicious
# 29     malicious
# ...          ...
# 45250  malicious
# 45251  malicious
# 45252  malicious
# 45253  malicious
# 45254  malicious
# 45255  malicious
# 45256  malicious
# 45257  malicious
# 45258  malicious
# 45259  malicious
# 45260  malicious
# 45261  malicious
# 45262  malicious
# 45263  malicious
# 45264  malicious
# 45265  malicious
# 45266  malicious
# 45267  malicious
# 45268  malicious
# 45269  malicious
# 45270  malicious
# 45271  malicious
# 45272  malicious
# 45273  malicious
# 45274  malicious
# 45275  malicious
# 45276  malicious
# 45277  malicious
# 45278  malicious
# 45279  malicious
#
# [45280 rows x 2 columns]

# %%
# Instantiate Vectorizer
vectorizer = TfidfVectorizer(max_df=.5, min_df=.001) #, stop_words=['abuse'])
# Fit
features_transformed = vectorizer.fit_transform(df.url)
vocab = vectorizer.vocabulary_

# %%
vocab
# Out:
# {'000webhostapp': 0,
#  '01': 1,
#  '09': 2,
#  '10': 3,
#  '10065877425': 4,
#  '1033': 5,
#  '12': 6,
#  '120': 7,
#  '1252899642': 8,
#  '129': 9,
#  '13698': 10,
#  '13inboxlight': 11,
#  '13inboxlightaspxn': 12,
#  '13vqcr8bp0gud': 13,
#  '14750ef6ccc9d69c326c97bf81a1ac34': 14,
#  '162': 15,
#  '163': 16,
#  '1774256418': 17,
#  '185': 18,
#  '1error': 19,
#  '20': 20,
#  '2016': 21,
#  '2017': 22,
#  '2018': 23,
#  '20account': 24,
#  '20auto': 25,
#  '20dqo8c3r5bgu': 26,
#  '20igjvzhkgeybtyxjnaw46ida7ig92zxjmbg93oiboawrkzw47ih0gpc9zdhlszt4nciagpglmcmft': 27,
#  '20in': 28,
#  '20now': 29,
#  '23': 30,
#  '230': 31,
#  '234': 32,
#  '2f': 33,
#  '2fwww': 34,
#  '3a': 35,
#  '3d1774256418': 36,
#  '3fn': 37,
#  '40b': 38,
#  '5183999': 39,
#  '51jianli': 40,
#  '52': 41,
#  '64855': 42,
#  '70': 43,
#  '_93894574342hdfjsixaoweue5_j1489738549283781331983743fncn_product': 44,
#  '_account': 45,
#  '_jehfuq_vjoxk0qwhtogydw_product': 46,
#  '_pagelabel': 47,
#  'abuse': 48,
#  'ac': 49,
#  'access': 50,
#  'account': 51,
#  'accounts': 52,
#  'accountverification': 53,
#  'acct': 54,
#  'acesiansystems': 55,
#  'act': 56,
#  'action': 57,
#  'active': 58,
#  'actor': 59,
#  'admin': 60,
#  'administrator': 61,
#  'adobe': 62,
#  'adobecom': 63,
#  'ae': 64,
#  'afstandsbediening': 65,
#  'ahaslo': 66,
#  'aissa': 67,
#  'alexanderperfumery': 68,
#  'alibaba': 69,
#  'all': 70,
#  'alt': 71,
#  'am': 72,
#  'amazon': 73,
#  'ameli': 74,
#  'ameliassurance': 75,
#  'ameliassurane': 76,
#  'amp': 77,
#  'andoburg': 78,
#  'answer': 79,
#  'aol': 80,
#  'api': 81,
#  'app': 82,
#  'apple': 83,
#  'appmanager': 84,
#  'ar': 85,
#  'arch': 86,
#  'archive': 87,
#  'armtrans': 88,
#  'asb': 89,
#  'asp': 90,
#  'aspx': 91,
#  'aspxn': 92,
#  'assets': 93,
#  'assistance': 94,
#  'assurance': 95,
#  'assure': 96,
#  'assure_somtc': 97,
#  'at': 98,
#  'att': 99,
#  'attiinnddeexx': 100,
#  'attt': 101,
#  'au': 102,
#  'aug': 103,
#  'auth': 104,
#  'auto': 105,
#  'ayo1': 106,
#  'ayv': 107,
#  'az': 108,
#  'ba': 109,
#  'bace': 110,
#  'bank': 111,
#  'banking': 112,
#  'bankofamerica': 113,
#  'base64': 114,
#  'battle': 115,
#  'bayar': 116,
#  'bd': 117,
#  'be': 118,
#  'beez3': 119,
#  'beget': 120,
#  'bid': 121,
#  'billing': 122,
#  'bin': 123,
#  'biokamakozmetik': 124,
#  'bisnessapps': 125,
#  'bit': 126,
#  'bitly': 127,
#  'biz': 128,
#  'biz_type': 129,
#  'blog': 130,
#  'bloggingfornetworking': 131,
#  'blogspot': 132,
#  'blue': 133,
#  'bmjahealthcaresolutions': 134,
#  'boa': 135,
#  'board': 136,
#  'bob': 137,
#  'bofa': 138,
#  'bookmark': 139,
#  'bookmark_apps': 140,
#  'bookmarks': 141,
#  'box': 142,
#  'br': 143,
#  'business': 144,
#  'by': 145,
#  'ca': 146,
#  'cache': 147,
#  'campolino': 148,
#  'canvashub': 149,
#  'capitalone': 150,
#  'card': 151,
#  'cbcxt': 152,
#  'cc': 153,
#  'cd': 154,
#  'centre': 155,
#  'cf': 156,
#  'cgi': 157,
#  'ch': 158,
#  'cha': 159,
#  'charset': 160,
#  'chase': 161,
#  'check': 162,
#  'chekpoint': 163,
#  'china': 164,
#  'chines': 165,
#  'cibc': 166,
#  'ciibigpicture': 167,
#  'cina': 168,
#  'cl': 169,
#  'cle': 170,
#  'cli': 171,
#  'client': 172,
#  'clientid': 173,
#  'clients': 174,
#  'cmb': 175,
#  'cmd': 176,
#  'cmnxer': 177,
#  'cn': 178,
#  'cndoubleegret': 179,
#  'co': 180,
#  'code': 181,
#  'colors': 182,
#  'combee84': 183,
#  'commb': 184,
#  'communication': 185,
#  'components': 186,
#  'concept': 187,
#  'config': 188,
#  'configuration': 189,
#  'confirm': 190,
#  'confirmation': 191,
#  'connect': 192,
#  'connexion_compte': 193,
#  'contact': 194,
#  'content': 195,
#  'cool': 196,
#  'count': 197,
#  'country': 198,
#  'crm_mtn_tracelog_task_id': 199,
#  'crop': 200,
#  'crypt': 201,
#  'css': 202,
#  'customer': 203,
#  'customer_center': 204,
#  'customerid': 205,
#  'customize': 206,
#  'customlogomatsng': 207,
#  'cz': 208,
#  'd3': 209,
#  'dafunc': 210,
#  'data': 211,
#  'dataque': 212,
#  'datarescue': 213,
#  'date': 214,
#  'db': 215,
#  'de': 216,
#  'default': 217,
#  'defaults': 218,
#  'details': 219,
#  'dhl': 220,
#  'dhlauto': 221,
#  'diff': 222,
#  'digitale': 223,
#  'dir': 224,
#  'dispatch': 225,
#  'dispatched': 226,
#  'dist': 227,
#  'dk': 228,
#  'do': 229,
#  'doc': 230,
#  'docs': 231,
#  'document': 232,
#  'documents': 233,
#  'docusign': 234,
#  'docx': 235,
#  'domain': 236,
#  'done': 237,
#  'download': 238,
#  'dpbx': 239,
#  'dqo8c3r5bgu': 240,
#  'drive': 241,
#  'drop': 242,
#  'dropbox': 243,
#  'dropboxhtml': 244,
#  'dropboxnew': 245,
#  'dropbx': 246,
#  'dropfile': 247,
#  'dujadah': 248,
#  'dxmbox': 249,
#  'editor': 250,
#  'edu': 251,
#  'ee': 252,
#  'em': 253,
#  'email': 254,
#  'emailaccess': 255,
#  'en': 256,
#  'en_us': 257,
#  'english': 258,
#  'enligne': 259,
#  'enterprise': 260,
#  'equipment': 261,
#  'error': 262,
#  'es': 263,
#  'espace': 264,
#  'espv': 265,
#  'eu': 266,
#  'ew': 267,
#  'example': 268,
#  'excel': 269,
#  'executiveimagenutrition': 270,
#  'expires': 271,
#  'facebook': 272,
#  'facture': 273,
#  'fav': 274,
#  'fb': 275,
#  'fb_bmpos': 276,
#  'fb_source': 277,
#  'fi': 278,
#  'fid': 279,
#  'file': 280,
#  'files': 281,
#  'filewords': 282,
#  'fixleaks': 283,
#  'flash': 284,
#  'folder': 285,
#  'fonts': 286,
#  'foreverdivine': 287,
#  'form': 288,
#  'forms': 289,
#  'fotozas': 290,
#  'fr': 291,
#  'free': 292,
#  'freeemailextractor': 293,
#  'ga': 294,
#  'gandjaircraft': 295,
#  'gano': 296,
#  'garden': 297,
#  'gd': 298,
#  'gdoc': 299,
#  'gdocs': 300,
#  'ge': 301,
#  'generale': 302,
#  'gifpdf': 303,
#  'gl': 304,
#  'global': 305,
#  'gmail': 306,
#  'go': 307,
#  'goo': 308,
#  'google': 309,
#  'googledoc': 310,
#  'gov': 311,
#  'gq': 312,
#  'gr': 313,
#  'greendatainfo': 314,
#  'gssss': 315,
#  'guide': 316,
#  'hakdilaravakfi': 317,
#  'headonradionetwork': 318,
#  'help': 319,
#  'herdadeperdigao': 320,
#  'himelsatellitecable': 321,
#  'hitmanjazz': 322,
#  'home': 323,
#  'hookupload': 324,
#  'host': 325,
#  'hot': 326,
#  'hotis': 327,
#  'hotmail': 328,
#  'houston': 329,
#  'htm': 330,
#  'html': 331,
#  'https': 332,
#  'hu': 333,
#  'huawei': 334,
#  'ib': 335,
#  'id': 336,
#  'identity': 337,
#  'ie': 338,
#  'ieas': 339,
#  'igjvzhkgeybtyxjnaw46ida7ig92zxjmbg93oiboawrkzw47ih0gpc9zdhlszt4nciagpglmcmft': 340,
#  'ii': 341,
#  'image': 342,
#  'images': 343,
#  'img': 344,
#  'in': 345,
#  'inc': 346,
#  'include': 347,
#  'includes': 348,
#  'index': 349,
#  'index1': 350,
#  'index2': 351,
#  'index_2': 352,
#  'indexa': 353,
#  'indexxatt': 354,
#  'info': 355,
#  'info02887166ft': 356,
#  'information': 357,
#  'infos': 358,
#  'inner_page': 359,
#  'invoice': 360,
#  'io': 361,
#  'ion': 362,
#  'ip': 363,
#  'it': 364,
#  'itibr': 365,
#  'jardimdovalerestaurante': 366,
#  'jm': 367,
#  'joomla': 368,
#  'jp': 369,
#  'js': 370,
#  'jsp': 371,
#  'jualumni': 372,
#  'karesidentialestate': 373,
#  'ke': 374,
#  'key': 375,
#  'known': 376,
#  'kor': 377,
#  'kr': 378,
#  'lang': 379,
#  'language': 380,
#  'languages': 381,
#  'larah': 382,
#  'lc': 383,
#  'le': 384,
#  'lib': 385,
#  'libraries': 386,
#  'library': 387,
#  'link': 388,
#  'live': 389,
#  'lmages': 390,
#  'loading': 391,
#  'lob': 392,
#  'locale': 393,
#  'log': 394,
#  'login': 395,
#  'login2': 396,
#  'login_failed': 397,
#  'login_submit': 398,
#  'loginalibaba': 399,
#  'loginverification': 400,
#  'logon': 401,
#  'logs': 402,
#  'lol': 403,
#  'long': 404,
#  'look': 405,
#  'ly': 406,
#  'm1cr0': 407,
#  'mabanque': 408,
#  'mai': 409,
#  'mail': 410,
#  'mailbox': 411,
#  'mailboxfud': 412,
#  'main': 413,
#  'maint': 414,
#  'manage': 415,
#  'mani': 416,
#  'mann1': 417,
#  'mark': 418,
#  'marks': 419,
#  'mat': 420,
#  'match': 421,
#  'me': 422,
#  'media': 423,
#  'meee': 424,
#  'message': 425,
#  'microsoft': 426,
#  'microsoftonline': 427,
#  'mkt': 428,
#  'ml': 429,
#  'mobile': 430,
#  'mobilizing': 431,
#  'mod_breadcrumbs': 432,
#  'mod_mainmenu': 433,
#  'modules': 434,
#  'moncompte': 435,
#  'mpp': 436,
#  'mt': 437,
#  'munozbr': 438,
#  'mx': 439,
#  'my': 440,
#  'myaccount': 441,
#  'myfiles': 442,
#  'myfreesites': 443,
#  'nab': 444,
#  'nabib': 445,
#  'navigation': 446,
#  'nd': 447,
#  'net': 448,
#  'network': 449,
#  'new': 450,
#  'newdoc': 451,
#  'news': 452,
#  'ng': 453,
#  'nhabanq7': 454,
#  'nkhumanrights': 455,
#  'nl': 456,
#  'no': 457,
#  'nocache': 458,
#  'notice': 459,
#  'notifications': 460,
#  'now': 461,
#  'nz': 462,
#  'of': 463,
#  'office': 464,
#  'office365': 465,
#  'one': 466,
#  'onedrive': 467,
#  'online': 468,
#  'opc': 469,
#  'or': 470,
#  'order': 471,
#  'oreo': 472,
#  'org': 473,
#  'others': 474,
#  'ou': 475,
#  'ourtime': 476,
#  'ourtimesort': 477,
#  'outlook': 478,
#  'owa': 479,
#  'page': 480,
#  'page2': 481,
#  'page_logonform': 482,
#  'pages': 483,
#  'pandavillage': 484,
#  'pass': 485,
#  'pay': 486,
#  'payment': 487,
#  'payments': 488,
#  'paypal': 489,
#  'pdf': 490,
#  'pe': 491,
#  'pegasusprops': 492,
#  'personal': 493,
#  'pgh0bww': 494,
#  'ph': 495,
#  'php': 496,
#  'pk': 497,
#  'pl': 498,
#  'plantsgalore': 499,
#  'plugins': 500,
#  'pomo': 501,
#  'portailas': 502,
#  'portal': 503,
#  'post': 504,
#  'pp': 505,
#  'ppl': 506,
#  'press': 507,
#  'pro': 508,
#  'products': 509,
#  'proposal': 510,
#  'pt': 511,
#  'public': 512,
#  'py': 513,
#  'qes': 514,
#  'qponn': 515,
#  'raakstaging': 516,
#  'rand': 517,
#  'rbglogon': 518,
#  'rdc': 519,
#  'rdccc1': 520,
#  're': 521,
#  'reader': 522,
#  'recover': 523,
#  'recovery': 524,
#  'red': 525,
#  'redirect': 526,
#  'ref': 527,
#  'rem': 528,
#  'remboursement': 529,
#  'reminder': 530,
#  'reported': 531,
#  'resolution': 532,
#  'restored': 533,
#  'review': 534,
#  'rf': 535,
#  'ro': 536,
#  'rougexbcp': 537,
#  'rs': 538,
#  'ru': 539,
#  'run': 540,
#  'sa': 541,
#  'safe': 542,
#  'safety': 543,
#  'santander': 544,
#  'sc': 545,
#  'scan': 546,
#  'schoolsleuth': 547,
#  'se': 548,
#  'sec': 549,
#  'secure': 550,
#  'secured': 551,
#  'secured_page': 552,
#  'security': 553,
#  'server': 554,
#  'service': 555,
#  'services': 556,
#  'session': 557,
#  'set': 558,
#  'settings': 559,
#  'settings_nav': 560,
#  'sg': 561,
#  'share': 562,
#  'shop': 563,
#  'si': 564,
#  'sign': 565,
#  'sign_in': 566,
#  'signed_key': 567,
#  'signin': 568,
#  'simplepie': 569,
#  'sinulogrealty': 570,
#  'site': 571,
#  'sites': 572,
#  'sitey': 573,
#  'sk': 574,
#  'skin': 575,
#  'smilies': 576,
#  'smokesonstate': 577,
#  'sms': 578,
#  'sms2': 579,
#  'snsc': 580,
#  'solacewarehousing': 581,
#  'source': 582,
#  'srcid': 583,
#  'ssl': 584,
#  'sslagentshm1': 585,
#  'staging': 586,
#  'step1': 587,
#  'step2': 588,
#  'storage': 589,
#  'straighdropbox': 590,
#  'stream': 591,
#  'stsgroupbd': 592,
#  'submit': 593,
#  'support': 594,
#  'syshainc': 595,
#  'system': 596,
#  'tab': 597,
#  'tanlaonline': 598,
#  'tbmjan092017': 599,
#  'tech': 600,
#  'templates': 601,
#  'test': 602,
#  'text': 603,
#  'theabstractprincess': 604,
#  'theme': 605,
#  'themes': 606,
#  'tinymce': 607,
#  'tk': 608,
#  'tmp': 609,
#  'tmpl': 610,
#  'tmweb': 611,
#  'to': 612,
#  'tolu': 613,
#  'tr': 614,
#  'tracking': 615,
#  'tripod': 616,
#  'true': 617,
#  'trusturman': 618,
#  'tz': 619,
#  'ua': 620,
#  'ubh': 621,
#  'uk': 622,
#  'unblock': 623,
#  'unblocking': 624,
#  'united': 625,
#  'up': 626,
#  'update': 627,
#  'updates': 628,
#  'upgrade': 629,
#  'upload': 630,
#  'uploads': 631,
#  'url': 632,
#  'us': 633,
#  'user': 634,
#  'userid': 635,
#  'users': 636,
#  'utf': 637,
#  'valid': 638,
#  'validate': 639,
#  'validation': 640,
#  've': 641,
#  'verif': 642,
#  'verification': 643,
#  'verify': 644,
#  'view': 645,
#  'viewer': 646,
#  'views': 647,
#  'vineyard': 648,
#  'vinotecataste': 649,
#  'visapayments': 650,
#  'vn': 651,
#  'vqcr8bp0gud': 652,
#  'warning': 653,
#  'web': 654,
#  'webapps': 655,
#  'webmail': 656,
#  'websc_login': 657,
#  'webscr': 658,
#  'website': 659,
#  'websrc': 660,
#  'well': 661,
#  'wells': 662,
#  'wellsfargo': 663,
#  'widgets': 664,
#  'wo9spdzhykzcx2hxhwi8igyrqlqdqot': 665,
#  'wordpress': 666,
#  'wp': 667,
#  'wr': 668,
#  'ws': 669,
#  'www': 670,
#  'xmlprdot': 671,
#  'xn': 672,
#  'xs': 673,
#  'xyz': 674,
#  'y1': 675,
#  'yah': 676,
#  'yahoo': 677,
#  'yahoologin': 678,
#  'yes': 679,
#  'your': 680,
#  'yradftyv': 681,
#  'za': 682,
#  'zip': 683}

# %%
def top_tfidf(vectorizer, fit_transform_result, topn=20):
    scores = zip(vectorizer.get_feature_names(), np.asarray(fit_transform_result.sum(axis=0)).ravel())
    sorted_scores = sorted(scores, key=lambda x: x[1], reverse=True)
    for item in sorted_scores[0:topn]:
        print("{0:50} Score: {1}".format(item[0], item[1]))

top_tfidf(vectorizer, features_transformed, topn=20)
# Out:
# www                                                Score: 2961.190084302796
# php                                                Score: 2797.8760450294217
# html                                               Score: 2269.0477926517606
# https                                              Score: 2099.234735520745
# amp                                                Score: 1959.8398245654153
# index                                              Score: 1573.566282176735
# wp                                                 Score: 1560.166389374524
# 000webhostapp                                      Score: 1453.9669529851258
# login                                              Score: 1410.6467786604208
# net                                                Score: 1049.3759580848232
# org                                                Score: 925.8204925515827
# htm                                                Score: 914.8349221342077
# includes                                           Score: 831.1866703978121
# admin                                              Score: 767.2462992235871
# update                                             Score: 762.5636725261315
# br                                                 Score: 754.4862892518354
# content                                            Score: 707.443124555139
# co                                                 Score: 678.4519387553534
# id                                                 Score: 670.9666739098985
# google                                             Score: 649.8635598795028

# %%
df[df.url.str.contains('wp')][['url', 'label']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                       url  \
# 2      http://52.70.129.120/js/.wp.php/rf/myaccount/34622/
# 3      http://52.70.129.120/js/.wp.php/rf/myaccount/34622/home?cmd=_account-details&session=626dcf1ea909ba1d031b89440d6ad034&dispatch=0405946fc903c08eb521696f62e245b18eadcfd7
# 56     http://www.balasdecocoribeirao.com.br/wp-content/themes/twentyfourteen/inc/first/verify/
# 60     http://crownfin.co.za/wp-content/plugins/sigma-wp/chase/home/index.php
# 243    http://eready.com/wp-content/content/msg-external-home/login.jsp.htm
# 268    https://www.birminghamonyork.com.au/mapmusez/vpresxe122/wp-drop2018/
# 278    http://www.satcomnet.com/glee/d41d8cd98f00b204e9800998ecf8427e/Up-dating4.php?country.x=-&ACCT.x=ID-PPL=PA324188.166.98.249=ScrPg=109523201732411dacb66f9f7b4f922834829049dc36145ce460af3e500fe6d3S=$1$KsBwpEiC$fu.vGk5yYy7Rbm/kUI6LX0in0bwkJu71CUj6XA2eH5hcQZSf9szKLpmIYv3ToBFl8GyRgOMqadNrVEDtx4PWS7XGmL9qhvYtAk21IJdbDVpyU6HZCl0nxOwr5fiMgE3QzoFaeNTKW8cjuPBR4s82318880498
# 292    https://mgmj.com/wp-includes/login.hpe.com/index.html
# 353    http://pwfurnishings.com/wp-admin/alibaba/alibaba/index.php?email=info@treescene.com
# 391    http://gepc.or.tz/wp/Office/index.html
# 393    http://birminghamonyork.com.au/mapmusez/vpresxe122/wp-drop2018/index.html
# 430    https://contentintent.com/wp-admin/network/THE-BATCH
# 431    https://contentintent.com/wp-admin/network/THE-BATCH/609abf48f84a7cca6b86e872b13f02a1/security.php?section=signinpage&update=&cookiecheck=yes&destination=nba/signin&accountopening/Applsection=signinpage&update=&cookiecheck=yes&destination=nba/signin&accountopening/ApplicationStartup/Application=&cookiecheck=yes&destinpage&update=&cookiecheck=icationStartup/Application=&cookiecheck=yes&destinpage&update=&cookiecheck
# 452    http://fionabradley.com/wp-content/plugins/ubh/wells/gzjzty=
# 453    http://fionabradley.com/wp-content/plugins/ubh/wells/gzjzty=/myaccount/emailaccess/
# 454    http://fionabradley.com/wp-content/plugins/ubh/wells/gzjzty=/myaccount/billing/
# 455    http://fionabradley.com/wp-content/plugins/ubh/wells/gzjzty=/myaccount/uploads/
# 460    http://jimmcavoy.org/wp-content/plugins/rss-importer/languages/drssf/newyah/vfrs.htm
# 473    http://meamode.com/Stephaniemarieglover/wp-includes/pomo/machine/wizzybaby/office.php
# 524    http://utasjsr.com/wp-content/plugins/css-ready-selectors/ilechristainming/index.html
# 571    http://www.kindsoulstudio.com/wp-content/plugins/hellobar/ynes/firstpage.html
# 573    http://honeyholidays.ca/wp-content/plugins/really-simple-captcha/gentium/hotis/step2-authen.php
# 574    http://honeyholidays.ca/wp-content/plugins/really-simple-captcha/gentium/hotis/index.php
# 624    http://www.projectcube.com.sg/wp-includes/lekyahoo/Y/ymail.html
# 626    https://foremostconstructionservices.com/wp-admin/network/step2.php
# 677    http://www.celmaisus.ro/wp-includes/ll.php/?rand=13InboxLightaspxn.1774256418&fid.4.1252899642&fid=1&fav.1&rand.13InboxLight.aspxn.1774256418&fid.1252899642&fid.1&fav.1&email=lcavender@tciway.tc&.rand=13InboxLight.aspx?n=1774256418&fid=4
# 696    http://www.thelulusband.com/wp-admin/css/colors/coffee/dropbox/domain/login.php?rand=WebAppSecurity.1&amp;amp;email=
# 699    https://honeyholidays.ca/wp-content/plugins/really-simple-captcha/gentium/hotis/step2-authen.php
# 700    https://honeyholidays.ca/wp-content/plugins/really-simple-captcha/gentium/hotis/index.php
# 703    http://white-space-studio-dev.com/joats/wp-content/fr/bc69b65846937e517cac342887e585a7/
# ...                                                                                        ...
# 44979  http://xn----7sbk8affkahdc3a.xn--p1ai/wp-includes/ID3/cas.htm
# 44980  http://xn----7sbk8affkahdc3a.xn--p1ai/wp-includes/Text/cas.htm
# 44982  http://xn----7sbk8affkahdc3a.xn--p1ai/wp-includes/fonts/cas.htm
# 44985  http://govtartscollege.com/wp-includes/aolmember/index.htm
# 44995  http://condramagee.com/wp-content/uploads/2012/10/Login.php
# 45009  http://www.rabbitfoodrocks.com/wp-includes/pomo/login.jsp.htm
# 45019  http://friendandcoach.com/wp-includes/images/wlw/doc252634536/
# 45021  http://friendandcoach.com/wp-includes/images/wlw/doc252634536
# 45022  http://friendandcoach.com/wp-includes/images/wlw/doc252634536/index.php
# 45053  http://www.simonkagyorgy.hu/wp-content/languages/forms.asp.htm
# 45057  http://goo.gl/wpOCYm
# 45058  http://izdeharalbasrah.com/wp/Ordersheet/weblogin.html
# 45059  http://sumaiao.com/wp-content/themes/googledrive/login/googledrive/googledoc.htm
# 45064  http://www.markgmedia.com.au/wp-admin/js/File/
# 45065  http://www.markgmedia.com.au/wp-includes/js/tinymce/file
# 45066  http://wp5.com.br/logs/Googledrive/
# 45072  http://www.jeffreybcam.net/wp-admin/new/administrator_restore.htm
# 45080  http://erlas.com.tr/wp-admin/user/GgG/google/
# 45081  http://erlas.com.tr/wp-admin/user/GgG/google
# 45100  http://www.rabbitfoodrocks.com/wp-content/plugins/wp-socializer/admin/templates/images/transf/?/s
# 45104  http://gesdoc.com.br/wp-includes/hongleongnew/index.htm
# 45129  http://xn--yeilkkocukevi-ngb7t35dea.com/wp-content/uploads/login.html
# 45152  http://51av.biz/wp-content/themes/wpfolio/6532414308/15474352342355/
# 45153  http://51av.biz/wp-content/themes/wpfolio/6532414308/623493258238184295/
# 45154  http://brgsti.com.br/v1/wp-includes/Text/LinkedIn.htm
# 45157  http://www.jeffreybcam.net/wp-admin/hom/websc/update.php
# 45163  http://buywebtechsolutions.com/wp-includes/js/file/docfile.htm
# 45203  http://patrickmarionbradley.com/wp-admin/images/rem/Remax/Remax/Secure Login.html
# 45204  http://sm3maja.waw.pl/wp-content/themes/duster/login_verify2.php
# 45212  http://connecticutspj.org/wp-content/uploads/2012/chasecustomerprofile/chasecustomerprofile/index.htm
#
#            label
# 2      malicious
# 3      malicious
# 56     malicious
# 60     malicious
# 243    malicious
# 268    malicious
# 278    malicious
# 292    malicious
# 353    malicious
# 391    malicious
# 393    malicious
# 430    malicious
# 431    malicious
# 452    malicious
# 453    malicious
# 454    malicious
# 455    malicious
# 460    malicious
# 473    malicious
# 524    malicious
# 571    malicious
# 573    malicious
# 574    malicious
# 624    malicious
# 626    malicious
# 677    malicious
# 696    malicious
# 699    malicious
# 700    malicious
# 703    malicious
# ...          ...
# 44979  malicious
# 44980  malicious
# 44982  malicious
# 44985  malicious
# 44995  malicious
# 45009  malicious
# 45019  malicious
# 45021  malicious
# 45022  malicious
# 45053  malicious
# 45057  malicious
# 45058  malicious
# 45059  malicious
# 45064  malicious
# 45065  malicious
# 45066  malicious
# 45072  malicious
# 45080  malicious
# 45081  malicious
# 45100  malicious
# 45104  malicious
# 45129  malicious
# 45152  malicious
# 45153  malicious
# 45154  malicious
# 45157  malicious
# 45163  malicious
# 45203  malicious
# 45204  malicious
# 45212  malicious
#
# [5875 rows x 2 columns]
