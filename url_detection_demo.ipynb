# %% [markdown]
# # Jaro Similarity
# <img src="images/jaro.png" width="80%">
#
# https://en.wikipedia.org/wiki/Jaro–Winkler_distance

# %% [markdown]
# # Levenshtein Distance
# <img src="images/levenshtein.png" width="80%">
#
# https://en.wikipedia.org/wiki/Levenshtein_distance

# %% [markdown]
# ## Let's Try It!

# %%
import jellyfish

# %%
# Levenshtein distance
jellyfish.levenshtein_distance('google.com', 'g00gle.com')
# Out:
# 2

# %%
# Jaro distance
jellyfish.jaro_distance('google.com', 'g00gle.com')
# Out:
# 0.8666666666666667

# %% [markdown]
# ## More!

# %%
words_to_compare = [(u'google.com', u'google.com'), 
                    (u'google.com', u'g00gle.com'),
                    (u'google.com', u'google.badguy.com'),
                    (u'google.com', u'malware.ru'),
                    (u'bit', u'bot'),
                    (u'bitly.bit', u'bitly.bot')]
for word1, word2 in words_to_compare:
    levenshtein = jellyfish.levenshtein_distance(word1, word2)
    jaro = jellyfish.jaro_distance(word1, word2)
    print("{} vs. {} Levenshtein: {} Jaro: {}".format(word1, word2, round(levenshtein, 3), round(jaro, 3)))
# Out:
# google.com vs. google.com Levenshtein: 0 Jaro: 1.0
# google.com vs. g00gle.com Levenshtein: 2 Jaro: 0.867
# google.com vs. google.badguy.com Levenshtein: 7 Jaro: 0.863
# google.com vs. malware.ru Levenshtein: 9 Jaro: 0.533
# bit vs. bot Levenshtein: 1 Jaro: 0.778
# bitly.bit vs. bitly.bot Levenshtein: 1 Jaro: 0.926

# %% [markdown]
# ## Finding Needles in a Haystack
# <img src="images/dataset.png" width="50%">

# %%
pd.set_option('large_repr', 'truncate')
pd.set_option('max_rows', 7)

# %%
# Load Dataset
import pandas as pd
pd.set_option('display.max_colwidth', 80)
df = pd.read_csv('./data/dataset_medium.csv', dtype={'port': str, 'subdomains':str})
df.fillna('', inplace=True)
df = df[['label', 'url', 'uri', 'subdomains']]
df.head(3)
# Out:
#     label                                             url                    uri subdomains
# 0  benign  https://coinmarketcap.com/historical/20140223/  /historical/20140223/
# 1  benign                       https://reddit.com/7wxie4                /7wxie4
# 2  benign                    https://youtu.be/M4QVkwY65wk           /M4QVkwY65wk

# %%
# Find common malicious
df[(df.label == 'malicious') & \
   (df.subdomains.str.contains('bank'))][['uri', 'subdomains', 'url']]
# Out:
#                                                                                     uri                                       subdomains                                                                              url
# 950128                               /account/verification/D50M74890M8414B93618/qes.php                               bankofamerica-com.  http://bankofamerica-com.microdeal.co.uk/account/verification/D50M74890M8414...
# 950152                                /aa892b70d8b0c077329c1baaa6800583/contactinfo.php                                  bankoffamerica.  http://bankoffamerica.webcindario.com/aa892b70d8b0c077329c1baaa6800583/conta...
# 950164                                                         /signonline/login.go.php      secure-bankofamerica.com.checking-accounts.  http://secure-bankofamerica.com.checking-accounts.osbirigui.com.br/signonlin...
# ...                                                                                 ...                                              ...                                                                              ...
# 998579                                      /vx/lang-en-GB/candidate/application/292496                               bankcampuscareers.     https://bankcampuscareers.tal.net/vx/lang-en-GB/candidate/application/292496
# 999288  /web/83bf4421703abebf1de652c240c2ca73f34f880c7ce03caa10fe10a3931a417c4d9c33e...  ebanking-ch-ubs-workbench-workbench-openaction.  http://ebanking-ch-ubs-workbench-workbench-openaction.storrien.com/web/83bf4...
# 999432                                               /1bae5192eb41949d09446761a144e460/                       www-hellobank-fr.toulone0.    http://www-hellobank-fr.toulone0.beget.tech/1bae5192eb41949d09446761a144e460/
#
# [215 rows x 3 columns]

# %%
malicious_uri = '/account/verification/D50M74890M8414B93618/qes.php'
df['jaro'] = df.uri.apply(jellyfish.jaro_distance, args=(malicious_uri,))
df[['label', 'url', 'jaro']].sort_values('jaro', ascending=False)[0:10]
# Out:
#             label                                                                              url      jaro
# 970632  malicious  https://bankofamerica-com.microdeal.co.uk/account/verification/D50M74890M841...  1.000000
# 950128  malicious  http://bankofamerica-com.microdeal.co.uk/account/verification/D50M74890M8414...  1.000000
# 988840  malicious  https://bankofamerica-com.microdeal.co.uk/account/verification/D50M74890M841...  0.961026
# ...           ...                                                                              ...       ...
# 958875  malicious  https://www.bofadatareview-bofa-com.ga/account/verification/E4M05EN65B112E71...  0.847480
# 971096  malicious  https://bankofamerica-com.microdeal.co.uk/account/verification/99AMDC2583N1C...  0.847480
# 956430  malicious  http://bankofamerica-com.microdeal.co.uk/account/verification/EBCMAC90A8D6B4...  0.839350
#
# [10 rows x 3 columns]

# %% [markdown]
# # TF-IDF
#
# A method to identify the importance of a word relative to the entire corpus

# %%
# Load TF-IDF Library
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# %%
# Let's do TF-IDF just on the malicious dataset
df_malicious = df[df.label=='malicious'][['label', 'url']]
df_malicious.head(5)
# Out:
#             label  \
# 950000  malicious
# 950001  malicious
# 950002  malicious
# 950003  malicious
# 950004  malicious
#
#                                                                                  url
# 950000                  http://byzcc.com/2017/index.php?email=abuse@rsresponse.co.uk
# 950001                                     http://m.facebook.udir.me/?_fb_noscript=1
# 950002  http://www.bloggingfornetworking.com/lmages/71884f5280caef99226832baf70ef980
# 950003                                  http://alsulthanscrap.com/AdminDB/index.html
# 950004          http://download-apk-files.ru/api/?name=StickMan%20Gun&amp;icon=http:

# %%
# Instantiate Vectorizer
vectorizer = TfidfVectorizer(max_df=.5, min_df=.001)
# Fit
features_transformed = vectorizer.fit_transform(df_malicious.url)
vocab = vectorizer.vocabulary_

# %%
vocab
# Out:
# {'https': 23694,
#  'www': 40806,
#  'islamicaid': 24858,
#  'youtu': 41379,
#  'be': 12846,
#  'sxvia0bto': 36888,
#  '79': 7769,
#  'limraexim': 26865,
#  'export': 20140,
#  'diffuser': 17901,
#  'data': 17229,
#  'aspx': 11624,
#  'imgur': 24263,
#  'tkkc0av': 37838,
#  'jpg': 25431,
#  'ul263yb': 38729,
#  'png': 31846,
#  'en': 19622,
#  'wikipedia': 40416,
#  'org': 30602,
#  'wiki': 40408,
#  'issues_affecting_the_single_transferable_vote': 24878,
#  'tactical_voting': 37001,
#  'magiccards': 27519,
#  'info': 24466,
#  'query': 32907,
#  'ugin': 38680,
#  '2c': 3872,
#  '20the': 3011,
#  '20spirit': 2981,
#  '20dragon': 2716,
#  'justice': 25563,
#  'gov': 22463,
#  'usao': 39052,
#  'sdca': 34728,
#  'pr': 32134,
#  'bank': 12560,
#  'pleads': 31774,
#  'guilty': 22736,
#  'pays': 31233,
#  'historic': 23352,
#  'penalty': 31342,
#  'concealing': 16043,
#  'anti': 11187,
#  'money': 28671,
#  'laundering': 26511,
#  'failures': 20494,
#  'quickship': 32924,
#  'quartet': 32896,
#  'porcelain': 31988,
#  'magnetic': 27526,
#  'in': 24322,
#  'and': 11078,
#  'out': 30718,
#  'board': 13553,
#  'huffingtonpost': 23715,
#  'glennon': 22225,
#  'melton': 28070,
#  'this': 37657,
#  'brilliant': 13847,
#  'math': 27855,
#  'teacher': 37164,
#  'has': 23011,
#  'formula': 21326,
#  'to': 37900,
#  'save': 34507,
#  'kids': 25913,
#  'lives_b_4899349': 26986,
#  'html': 23681,
#  'sadeed': 34327,
#  'io': 24754,
#  'pricing': 32246,
#  'php': 31558,
#  'uvvev8j': 39164,
#  'artisticmadmann': 11536,
#  'deviantart': 17739,
#  'b7lqny0': 12343,
#  'cehrd9s': 14982,
#  'mbmbam': 27912,
#  'wikia': 40409,
#  'episode_253': 19787,
#  '_bye': 9520,
#  'bye_boy': 14124,
#  'betofortexas': 13070,
#  'robertlindsay': 33947,
#  'wordpress': 40622,
#  '2017': 2417,
#  '07': 324,
#  '23': 3243,
#  'major': 27585,
#  'changes': 15173,
#  'the': 37396,
#  'private': 32286,
#  'delphi': 17567,
#  'murders': 28974,
#  'fora': 21278,
#  'pension_fund_of_the_russian_federation': 31362,
#  'paladins': 31004,
#  'guru': 22768,
#  'profile': 32362,
#  'pc': 31253,
#  'poison1999': 31879,
#  'champions': 15160,
#  'openload': 30530,
#  'co': 15761,
#  'hyrrz3xjtym': 23809,
#  'life': 26802,
#  'undergrowth': 38810,
#  's01e02': 34249,
#  '720p': 7462,
#  'webrip': 40134,
#  'x264': 40858,
#  'ngp': 29644,
#  'mkv': 28495,
#  'mp4': 28822,
#  'classicstreamliners': 15570,
#  'npt': 29956,
#  'duquesne': 18677,
#  'imagizer': 24225,
#  'imageshack': 24223,
#  'us': 39029,
#  'img924': 24246,
#  '6792': 7023,
#  'fu9dks': 21578,
#  'google': 22392,
#  'search': 34758,
#  'boston': 13675,
#  'apartments': 11244,
#  'overcrowding': 30766,
#  'pixiv': 31683,
#  'net': 29462,
#  'member_illust': 28074,
#  'mode': 28607,
#  'medium': 28018,
#  'amp': 11033,
#  'illust_id': 24191,
#  '47305247': 5603,
#  'tagesschau': 37007,
#  'de': 17413,
#  'inland': 24552,
#  'deutschlandtrend': 17726,
#  '1109': 879,
#  'howtogeek': 23614,
#  '117192': 948,
#  'how': 23602,
#  'run': 34173,
#  'powershell': 32096,
#  'commands': 15943,
#  'on': 30423,
#  'remote': 33548,
#  'computers': 16030,
#  'emojipedia': 19593,
#  'skateboard': 35576,
#  'github': 22179,
#  'pauldotknopf': 31201,
#  'windowssdk7': 40458,
#  'samples': 34424,
#  'blob': 13431,
#  'master': 27834,
#  'security': 34864,
#  'certificateservices': 15059,
#  'policy': 31899,
#  '2b': 3815,
#  'windowsserver2008': 40459,
#  'ceformat': 14977,
#  'cpp': 16437,
#  'steamcommunity': 36371,
#  'id': 23944,
#  'owwnn3d': 30814,
#  'makeagif': 27595,
#  'gif': 22131,
#  'jvgjj': 25581,
#  'j4roj9n': 25011,
#  'pinimg': 31639,
#  '736x': 7534,
#  '5a': 6461,
#  'eb': 19095,
#  'f9': 20401,
#  '5aebf95ef56fc2455c002776efeb26a4': 6490,
#  'funda': 21614,
#  'nl': 29760,
#  'huur': 23757,
#  'utrecht': 39146,
#  'dogsnaturallymagazine': 18246,
#  'give': 22184,
#  'your': 41364,
#  'dog': 18234,
#  'ginger': 22161,
#  'goo': 22365,
#  'gl': 22205,
#  'images': 24218,
#  'a5lhmq': 9818,
#  'icj': 23923,
#  'international': 24666,
#  'mission': 28440,
#  'of': 30235,
#  'jurists': 25554,
#  'singapore': 35488,
#  'dismisses': 18021,
#  'allegations': 10843,
#  'marxist': 27798,
#  'conspiracy': 16155,
#  'dashboard': 17224,
#  'altcoinanalytics': 10908,
#  '6sblf1tsoaw': 7340,
#  's14': 34264,
#  'postimg': 32063,
#  'wwpwxk335': 40803,
#  'shootergame': 35292,
#  'win32': 40449,
#  'shipping_2018_02_14_23_41_39_369': 35274,
#  'faithwire': 20502,
#  '10': 702,
#  '13': 1151,
#  'cleansed': 15583,
#  'reborn': 33288,
#  'jesus': 25209,
#  'name': 29234,
#  'check': 15255,
#  'philadelphia': 31510,
#  'eagles': 19045,
#  'using': 39101,
#  'hotel': 23571,
#  'pool': 31960,
#  'for': 21277,
#  'baptism': 12592,
#  'prior': 32276,
#  'last': 26482,
#  'nights': 29694,
#  'big': 13189,
#  'game': 21771,
#  'speakev': 36031,
#  'threads': 37689,
#  'eu': 19955,
#  'charging': 15197,
#  'legislation': 26651,
#  '99641': 9267,
#  'tumblr': 38370,
#  '37a298b0fe96247faa9a5d0c9dfdcdb4': 4753,
#  'tumblr_p4ve2ycz2w1x1hpcco1_raw': 38422,
#  'wqrte': 40720,
#  'bridge': 13836,
#  'registry': 33485,
#  'fm': 21196,
#  'music': 28991,
#  'musta': 29004,
#  'paraati': 31055,
#  'gatherer': 21853,
#  'wizards': 40521,
#  'pages': 30970,
#  'card': 14643,
#  'details': 17707,
#  'homing': 23507,
#  '20sliver': 2971,
#  'instagram': 24599,
#  'becjrgrfdsy': 12912,
#  'youtube': 41380,
#  'watch': 39984,
#  'vw4kvoevcr0': 39812,
#  'idddt': 23965,
#  'amazon': 10954,
#  'gp': 22475,
#  'product': 32331,
#  'b00x84loz0': 12075,
#  'ref': 33432,
#  'oh_aui_search_detailpage': 30318,
#  'ie': 24074,
#  'utf8': 39127,
#  'psc': 32516,
#  'gayforit': 21867,
#  'video': 39502,
#  '245843': 3362,
#  'lucas': 27315,
#  'bareback': 12607,
#  'spiegel': 36079,
#  'germany': 22026,
#  'anger': 11116,
#  'over': 30760,
#  'baader': 12416,
#  'meinhof': 28047,
#  'biopic': 13286,
#  'victims': 39489,
#  'families': 20525,
#  'uproar': 38981,
#  'new': 29512,
#  'german': 22023,
#  'terrorism': 37300,
#  'film': 20975,
#  '582894': 6363,
#  'lexpress': 26732,
#  'fr': 21390,
#  'actualite': 10276,
#  'politique': 31926,
#  'quand': 32887,
#  'lellouche': 26668,
#  'menace': 28103,
#  'melenchon': 28056,
#  'le': 26568,
#  'flinguer': 21150,
#  'duel_751951': 18655,
#  'lparchive': 27264,
#  'fire': 21033,
#  'emblem': 19563,
#  'path': 31182,
#  'radiance': 33036,
#  'cannabis': 14582,
#  '22ulcerative': 3240,
#  'colitis': 15836,
#  '22': 3152,
#  'oq': 30573,
#  'rac': 33013,
#  'au': 11766,
#  'car': 14633,
#  'motoring': 28779,
#  'running': 34179,
#  'costs': 16346,
#  'kaiserscience': 25672,
#  'files': 20961,
#  '2015': 2395,
#  '08': 357,
#  'thermodynamics': 37589,
#  'laws': 26522,
#  'birds': 13296,
#  '960': 9020,
#  'uxiyp': 39180,
#  '0ip810n': 612,
#  'drweil': 18583,
#  'health': 23097,
#  'wellness': 40219,
#  'body': 13579,
#  'mind': 28371,
#  'spirit': 36093,
#  'addiction': 10326,
#  'alcoholism': 10767,
#  'deertier': 17508,
#  'leaderboard': 26572,
#  'anypercentrealtime': 11212,
#  'dr': 18414,
#  'dk': 18091,
#  'nyheder': 30083,
#  'penge': 31350,
#  'kontant': 26142,
#  'saadan': 34307,
#  'goer': 22327,
#  'du': 18638,
#  'hvis': 23763,
#  'bliver': 13424,
#  'fanget': 20539,
#  'abonnementsfaelde': 10085,
#  'eqgzdjj': 19800,
#  'static': 36339,
#  'studiobebop': 36613,
#  'ygo_data': 41262,
#  'card_images': 14646,
#  'stray_asmodian': 36543,
#  'twitter': 38488,
#  'shirabii': 35276,
#  'status': 36358,
#  '774336965374119937': 7705,
#  'scp': 34672,
#  '005': 42,
#  'pe8ka9p': 31306,
#  'wpqcolq': 40702,
#  'resi': 33638,
#  'ze': 41587,
#  'robot': 33959,
#  'dl': 18102,
#  'sh': 35159,
#  'shadow': 35167,
#  'colossus': 15867,
#  '768': 7671,
#  '1024': 760,
#  'archiveofourown': 11395,
#  'works': 40643,
#  '1109359': 880,
#  'rio1mzj4tj': 33854,
#  'richardfitchen': 33802,
#  'wp': 40690,
#  'content': 16189,
#  'uploads': 38969,
#  '01': 81,
#  'income': 24351,
#  'tax': 37102,
#  'marginal': 27734,
#  'rates': 33150,
#  'copy': 16276,
#  'feature': 20774,
#  '4b9zfw3jhv8': 5777,
#  'sooyoungnews': 35926,
#  '966303161005654016': 9129,
#  'healthreformbeyondthebasics': 23102,
#  'webinar': 40105,
#  'oe5': 30228,
#  '07_seps': 348,
#  'updates': 38939,
#  'verification': 39388,
#  'pdf': 31286,
#  'ems1': 19615,
#  'ems': 19614,
#  'products': 32345,
#  'personal': 31410,
#  'protective': 32467,
#  'equipment': 19805,
#  'ppe': 32110,
#  'articles': 11522,
#  '197601048': 1959,
#  'important': 24293,
#  'items': 24920,
#  'paramedics': 31069,
#  'should': 35330,
#  'wearing': 40067,
#  'but': 14071,
#  'arent': 11412,
#  'ww2db': 40794,
#  'image': 24209,
#  'image_id': 24212,
#  '18517': 1858,
#  'roadfood': 33930,
#  '2016': 2403,
#  '03': 177,
#  'rfl_3230': 33762,
#  'notebookcheck': 29896,
#  'mobile': 28564,
#  'graphics': 22552,
#  'cards': 14662,
#  'benchmark': 13007,
#  'list': 26920,
#  '844': 8342,
#  'whoonew': 40381,
#  'closer': 15652,
#  'look': 27193,
#  'why': 40386,
#  'bubbler': 13953,
#  'wisconsin': 40493,
#  'facebook': 20445,
#  'orlandodelcid': 30633,
#  'ehrmanblog': 19373,
#  'as': 11558,
#  'god': 22315,
#  'synoptics': 36905,
#  'members': 28076,
#  'es': 19858,
#  'pcpartpicker': 31263,
#  'ft8j4d': 21562,
#  'crucial': 16590,
#  'mx500': 29035,
#  '500gb': 5961,
#  '25': 3406,
#  'solid': 35874,
#  'state': 36331,
#  'drive': 18473,
#  'ct500mx500ssd1': 16658,
#  'fungi': 21625,
#  'blog': 13444,
#  'bee': 12928,
#  'friendly': 21506,
#  'research': 33624,
#  'update': 38925,
#  'edhrec': 19236,
#  'living': 26991,
#  '20end': 2744,
#  'libdems': 26773,
#  'uk': 38709,
#  'negotiations': 29423,
#  'government': 22466,
#  'no': 29792,
#  'plan': 31712,
#  'idea': 23968,
#  '66ucs': 6978,
#  'ecestaticos': 19162,
#  'clipping': 15641,
#  '939': 8890,
#  '24077198673134920060645be5eabf9c': 3337,
#  'manifestacion': 27671,
#  'del': 17543,
#  'hogar': 23450,
#  'social': 35823,
#  'madrid': 27495,
#  'foto': 21352,
#  'daniel': 17187,
#  'munoz': 28968,
#  'galeota': 21753,
#  'ml': 28496,
#  'galeoata': 21752,
#  '5_27': 6459,
#  'chicagotribune': 15325,
#  'news': 29576,
#  'opinion': 30544,
#  'commentary': 15950,
#  'ct': 16657,
#  'trump': 38274,
#  'nunes': 30043,
#  'memo': 28090,
#  'release': 33513,
#  '20180202': 2455,
#  'story': 36503,
#  'uwantme2killhim': 39170,
#  '3f': 5069,
#  'isbi8dp9urc': 24840,
#  '166': 1628,
#  'wql2ypj7a6o': 40717,
#  'bgpnu': 13147,
#  'aidvu': 10662,
#  'commandcenter': 15940,
#  'blogspot': 13453,
#  '12': 991,
#  'error': 19844,
#  'handling': 22943,
#  'upspin': 38989,
#  'ybctyb_yn7q': 41196,
#  'b55zp': 12290,
#  'ppmsuyggi': 32121,
#  '6musfvc': 7311,
#  'wikidot': 40411,
#  '055': 272,
#  'thegrandline': 37506,
#  'odanon': 30214,
#  'htm': 23679,
#  'farcrymods': 20561,
#  'freeforums': 21445,
#  'thread': 37685,
#  '499': 5708,
#  'disc': 17980,
#  'rifle': 33831,
#  'cut': 16765,
#  'bostonmagazine': 13677,
#  '11': 872,
#  'massachusetts': 27820,
#  'gun': 22751,
#  'death': 17448,
#  'rate': 33148,
#  'gfycat': 22072,
#  'impracticalhealthygreatdane': 24302,
#  'aeroking': 10503,
#  'jeroencryptone': 25195,
#  'tnqui039a2s': 37897,
#  'l1cmaax': 26323,
#  'gh6d7fc_pwu': 22093,
#  'bhphotovideo': 13162,
#  '1326484': 1176,
#  'reg': 33464,
#  'sony_alpha_a6000_mirrorless_digital': 35921,
#  'imgflip': 24257,
#  '23g0r1': 3327,
#  'kugipvj': 26245,
#  'ov': 30753,
#  'overlord': 30771,
#  'fellowship': 20820,
#  'evil': 20023,
#  '2560': 3459,
#  '1440': 1308,
#  'zzmt9byg7ui': 41784,
#  'jalapeno': 25054,
#  'garlic': 21830,
#  'stuffed': 36619,
#  'olives': 30388,
#  'page': 30952,
#  'rh': 33777,
#  '3aaps': 4893,
#  '2ck': 3930,
#  '3ajalapeno': 4906,
#  '20garlic': 2782,
#  '20stuffed': 2990,
#  '20olives': 2882,
#  'sikhiwiki': 35439,
#  'index': 24376,
#  'the_hindu_sacred_thread': 37416,
#  'brian': 13822,
#  'doyle': 18380,
#  '2011': 2361,
#  '28': 3669,
#  'convolution': 16243,
#  'vs': 39768,
#  'algorithmic': 10797,
#  'reverbs': 33721,
#  'pewforum': 31445,
#  '26': 3498,
#  'political': 31915,
#  'views': 39539,
#  'phobia': 31531,
#  'mechanophobia': 27973,
#  'samharrisorg': 34415,
#  '692070165274492928': 7082,
#  'lang': 26446,
#  'store': 36490,
#  'steampowered': 36374,
#  'app': 11275,
#  '397190': 4842,
#  'sengoku_jidai_shadow_of_the_shogun': 34967,
#  'inhdw': 24538,
#  '8k': 8707,
#  'blade': 13397,
#  'runner': 34177,
#  '2049': 2553,
#  'movie': 28806,
#  'sci': 34618,
#  'fi': 20896,
#  'art': 11485,
#  '2013': 2378,
#  '56': 6250,
#  'c3': 14237,
#  '9745mm_nato': 9188,
#  'improvements': 24312,
#  'item': 24899,
#  'taobao': 37071,
#  '12378286453': 1052,
#  'cwlvh12_xy0': 16798,
#  'hsbcsortcodes': 23655,
#  '54j7meo': 6199,
#  'gifv': 22143,
#  'morejpeg': 28726,
#  'view': 39520,
#  '4f20d43b': 5871,
#  '0f19': 582,
#  'e811': 18967,
#  '80f0': 8202,
#  '9d5eaea625ba': 9370,
#  'jedit': 25165,
#  '20ojanen': 2880,
#  '20of': 2878,
#  '20efrava': 2738,
#  'platinum': 31736,
#  '20angel': 2601,
#  'eurogamer': 19970,
#  'digitalfoundry': 17918,
#  'ps3': 32510,
#  'hard': 22981,
#  'upgrade': 38953,
#  'guide': 22724,
#  'xbox': 40899,
#  'uservoice': 39092,
#  'forums': 21343,
#  '390042': 4823,
#  'parties': 31130,
#  'multiplayer': 28955,
#  'suggestions': 36680,
#  '7783044': 7722,
#  'block': 13433,
#  'messages': 28150,
#  'from': 21515,
#  'non': 29836,
#  'friends': 21508,
#  'bzrxidp': 14148,
#  'decathlon': 17467,
#  'rollentrainer': 34010,
#  'flow': 21171,
#  'smart': 35698,
#  't2240': 36950,
#  'x8345488': 40877,
#  'mc': 27915,
#  '8345488': 8301,
#  'grijs': 22612,
#  'ayw4p': 11981,
#  'wolflan': 40588,
#  'competitivecyclist': 15993,
#  'catalog': 14764,
#  'fitcalculatorbike': 21075,
#  'jsp': 25480,
#  'measures': 27961,
#  'buzzfeed': 14088,
#  'djpeisner': 18085,
#  'yid': 41282,
#  'army': 11460,
#  'goes': 22328,
#  'war': 39938,
#  'when': 40340,
#  'does': 18228,
#  'chanting': 15180,
#  'soccer': 35819,
#  'teams': 37177,
#  'utm_term': 39138,
#  'wfoeewe8d': 40304,
#  'vrroobomj': 39767,
#  'classroom': 15574,
#  'synonym': 36904,
#  'catholic': 14774,
#  'saints': 34370,
#  'pagan': 30949,
#  'gods': 22324,
#  '12085386': 1010,
#  'forum': 21339,
#  'paradoxplaza': 31063,
#  'quality': 32880,
#  'notice': 29901,
#  'that': 37391,
#  'ships': 35275,
#  'can': 14556,
#  'upgraded': 38957,
#  '1069296': 831,
#  'saab': 34306,
#  'ribbon': 33793,
#  'cable': 14446,
#  'pixel': 31676,
#  'repair': 33576,
#  'dp': 18383,
#  'b00bl6cecy': 12053,
#  'yours': 41372,
#  'original': 30622,
#  'piano': 31587,
#  'composition': 16013,
#  'my': 29044,
#  'first': 21051,
#  'three': 37696,
#  'years': 41224,
#  'canada': 14557,
#  '51e14861af5e': 6051,
#  'psc7csv': 32517,
#  'canyoumakeit': 14594,
#  'redbull': 33385,
#  'applications': 11315,
#  '10752': 835,
#  'weekinchina': 40183,
#  '06': 286,
#  'will': 40434,
#  'investors': 24735,
#  'lust': 27346,
#  'it': 24884,
#  'paddockspares': 30940,
#  'turbo': 38426,
#  'boost': 13647,
#  'box': 13701,
#  'td5': 37149,
#  'img00': 24240,
#  'c9ad': 14412,
#  '2014': 2389,
#  '137': 1225,
#  'if_modern_anarchists_fought_in_spain__part_1__by_rednblacksalamander': 24091,
#  'd7irpe5': 17033,
#  '5mpyul': 6636,
#  'politik': 31924,
#  'deutschland': 17723,
#  'tuerkei': 38360,
#  'deutsche': 17722,
#  'regierung': 33468,
#  'genehmigte': 21964,
#  'im': 24204,
#  'oktober': 30361,
#  'aufruestung': 11784,
#  'von': 39713,
#  'panzern': 31041,
#  '1189934': 963,
#  'who': 40377,
#  'int': 24621,
#  'hrh': 23645,
#  'statistics': 36350,
#  'hwfstats': 23766,
#  'illustriousmiserlydungbeetle': 24192,
#  'dinnerbone': 17949,
#  '961183194988072960': 9041,
#  '3dbuzz': 5018,
#  'training': 38095,
#  '3rd': 5167,
#  'person': 31408,
#  'character': 15189,
#  'system': 36914,
#  'dgcissuetracker': 17800,
#  'browse': 13893,
#  'ps': 32507,
#  '3487': 4573,
#  'gamesoflegends': 21798,
#  'champion': 15159,
#  'stats': 36354,
#  '90': 8751,
#  'tournament': 38015,
#  'na': 29209,
#  '20lcs': 2832,
#  '20spring': 2982,
#  '202018': 2518,
#  'engadget': 19685,
#  '05': 260,
#  'go': 22300,
#  'binge': 13266,
#  'plans': 31722,
#  'netflix': 29471,
#  'soundcloud': 35959,
#  'streaming': 36549,
#  'xhvzxgl': 40954,
#  '8bo54we_rju': 8606,
#  '1e144ceb21bef6dc5b6cb824e2eea884': 2122,
#  'tumblr_p410bhilse1x0kj9co1_raw': 38407,
#  'krios': 26198,
#  'shop': 35297,
#  'thehill': 37512,
#  'finance': 20996,
#  '371670': 4715,
#  'cbo': 14838,
#  'debt': 17463,
#  'limit': 26851,
#  'deadline': 17431,
#  'likely': 26836,
#  'half': 22912,
#  'march': 27717,
#  'looneytunes': 27201,
#  'reverse_psychology': 33724,
#  'krikienoid': 26194,
#  'flagwaver': 21113,
#  'src': 36205,
#  '3a': 4865,
#  '2f': 3993,
#  '2fi': 4098,
#  '2f6cn2r7d': 4026,
#  '2utroc0lfxy': 4271,
#  '2m44s': 4213,
#  'babywhispererforums': 12431,
#  'topic': 37967,
#  '84884': 8361,
#  'vancouversun': 39275,
#  'storyline': 36507,
#  'love': 27248,
#  'stop': 36481,
#  'donating': 18287,
#  'canned': 14583,
#  'goods': 22378,
#  'food': 21261,
#  'vsx7t': 39780,
#  'premiata': 32179,
#  'forneria': 21327,
#  'marconi': 27725,
#  'iilyilw': 24145,
#  'qld': 32818,
#  'transport': 38136,
#  'safety': 34346,
#  'fines': 21020,
#  'speed': 36054,
#  'cameras': 14537,
#  'combined': 15909,
#  'fanchus': 20537,
#  'tradeoffer': 38077,
#  'partner': 31132,
#  '113309151': 911,
#  'token': 37926,
#  'b1cowbua': 12200,
#  'member': 28073,
#  '573302': 6316,
#  'open': 30518,
#  'spotify': 36141,
#  'track': 38059,
#  '6ovqo8jwz5m0vmwk1hc3yq': 7324,
#  'shittysimpsonstattoos': 35284,
#  'hl': 23406,
#  'thefader': 37485,
#  '2012': 2366,
#  '14': 1273,
#  'beat': 12886,
#  'construction': 16161,
#  'el': 19420,
#  'vhxg7wv': 39479,
#  'archive': 11394,
#  'is': 24832,
#  'cvplw': 16783,
#  'norml': 29868,
#  'ca': 14423,
#  'senate': 34955,
#  'report': 33592,
#  'dailymail': 17137,
#  'pix': 31675,
#  '02': 138,
#  '16': 1577,
#  '3cbab17900000578': 4970,
#  '4179980': 5314,
#  '58_1485965063931': 6396,
#  'qhfjv': 32794,
#  'media1': 27986,
#  'tenor': 37261,
#  'c28ea9e2660c8b013559af4edcf8a45a': 14220,
#  'itemid': 24917,
#  '7915188': 7779,
#  'futhead': 21651,
#  '18': 1797,
#  'squads': 36175,
#  '2958162': 3760,
#  'twitch': 38487,
#  'tv': 38444,
#  'videos': 39511,
#  '219143982': 3136,
#  '93b072j': 8893,
#  'e3i': 18855,
#  'brosencephalon': 13883,
#  'flashcards': 21123,
#  'pisikakik': 31660,
#  'spcontrols': 36025,
#  'prodcat': 32327,
#  'hierid': 23289,
#  '32': 4409,
#  'smile': 35730,
#  'dads': 17122,
#  'nuke': 30021,
#  'marc': 27713,
#  'laidlaw': 26396,
#  '1555471471': 1524,
#  'sa': 34303,
#  'redirect': 33408,
#  'ivhnqx4': 24961,
#  '2wpgfuv': 4282,
#  'z0zfqkj': 41481,
#  'steamdb': 36372,
#  '373310': 4725,
#  'history': 23356,
#  '68efdf08c0b12dda3cc0193d09ea2a02': 7071,
#  '5123398': 6025,
#  'web': 40070,
#  'homenews': 23495,
#  'administration': 10385,
#  '373976': 4727,
#  'could': 16356,
#  'visit': 39609,
#  'area': 11406,
#  'school': 34608,
#  'shooting': 35294,
#  'while': 40351,
#  'at': 11684,
#  'mar': 27707,
#  'lago': 26391,
#  'eltiempo': 19518,
#  'politica': 31914,
#  'gobierno': 22310,
#  'santos': 34463,
#  'suspende': 36806,
#  'ciclo': 15436,
#  'dialogo': 17856,
#  'con': 16038,
#  'eln': 19503,
#  '176378': 1747,
#  'images4': 24221,
#  'ravelrycache': 33164,
#  'fromthemtn': 21522,
#  '235842798': 3292,
#  'cowlliam6_medium': 16413,
#  'i0': 23822,
#  'kym': 26294,
#  'cdn': 14927,
#  'photos': 31550,
#  '001': 25,
#  '327': 4441,
#  '296': 3763,
#  'b0a': 12173,
#  'cbc': 14823,
#  'radio': 33038,
#  'thecurrent': 37469,
#  'special': 36037,
#  'edition': 19245,
#  'current': 16727,
#  'january': 25074,
#  '2018': 2448,
#  '4503172': 5500,
#  'millennium': 28355,
#  'scoop': 34650,
#  'indigenous': 24426,
#  'youth': 41378,
#  'say': 34525,
#  'care': 14665,
#  'repeats': 33579,
#  'horrors': 23545,
#  'past': 31168,
#  '4503179': 5501,
#  'xgaming': 40942,
#  'arcade': 11384,
#  'tankstick': 37064,
#  'trackball': 38060,
#  'usb': 39056,
#  'included': 24345,
#  'nytimes': 30096,
#  'upshot': 38987,
#  'gender': 21961,
#  'pay': 31216,
#  'gap': 21816,
#  'largely': 26470,
#  'because': 12910,
#  'motherhood': 28764,
#  'uomgb': 38910,
#  'r695u': 32994,
#  'lazjygw': 26535,
#  'qio': 32805,
#  'antisemitism': 11197,
#  'utf': 39126,
#  'oe': 30227,
#  'client': 15611,
#  'firefox': 21042,
#  'ab': 10016,
#  'gfe_rd': 22058,
#  'cr': 16460,
#  'dcr': 17361,
#  'ei': 19377,
#  'etp0wswbb8rpxtfdo4gm': 19949,
#  'tv_': 38447,
#  'the_book': 37400,
#  '_two_experts_pick_the_greatest_american_shows_of_all_time': 9626,
#  'psychologytoday': 32555,
#  'spycatcher': 36165,
#  '201708': 2431,
#  'believe': 12985,
#  'me': 27953,
#  'concept2': 16048,
#  'indoor': 24437,
#  'rowers': 34078,
#  'tips': 37803,
#  'general': 21965,
#  'damper': 17168,
#  'setting': 35096,
#  '101': 741,
#  ...}

# %%
def top_tfidf(vectorizer, fit_transform_result, topn=20):
    scores = zip(vectorizer.get_feature_names(), np.asarray(fit_transform_result.sum(axis=0)).ravel())
    sorted_scores = sorted(scores, key=lambda x: x[1], reverse=True)
    for item in sorted_scores[0:topn]:
        print("{0:50} Score: {1:.3f}".format(item[0], item[1]))

top_tfidf(vectorizer, features_transformed, topn=20)
# Out:
# https                                              Score: 120044.553
# imgur                                              Score: 108367.614
# www                                                Score: 53651.943
# jpg                                                Score: 49357.261
# be                                                 Score: 36253.121
# youtu                                              Score: 36190.031
# org                                                Score: 28714.850
# png                                                Score: 26458.172
# wiki                                               Score: 22466.461
# en                                                 Score: 22046.400
# amp                                                Score: 20219.532
# wikipedia                                          Score: 19490.361
# twitter                                            Score: 15501.480
# html                                               Score: 12948.997
# net                                                Score: 12721.900
# youtube                                            Score: 12605.261
# status                                             Score: 11900.676
# watch                                              Score: 11473.189
# instagram                                          Score: 10108.690
# reddit                                             Score: 9366.602

# %%
# Redo with the entire dataset
features_transformed = vectorizer.fit_transform(df.url)
print(features_transformed.shape)
vocab = vectorizer.vocabulary_
top_tfidf(vectorizer, features_transformed, topn=25)
# Out:
# (1000000, 41796)
# https                                              Score: 120044.55274561205
# imgur                                              Score: 108367.61358839607
# www                                                Score: 53651.94264232749
# jpg                                                Score: 49357.26125641032
# be                                                 Score: 36253.12061804477
# youtu                                              Score: 36190.031198026896
# org                                                Score: 28714.850040695368
# png                                                Score: 26458.171645913455
# wiki                                               Score: 22466.46123095859
# en                                                 Score: 22046.399934650282
# amp                                                Score: 20219.532093269685
# wikipedia                                          Score: 19490.361005623367
# twitter                                            Score: 15501.480409950696
# html                                               Score: 12948.996609400014
# net                                                Score: 12721.899796687794
# youtube                                            Score: 12605.260616027328
# status                                             Score: 11900.67623459585
# watch                                              Score: 11473.189452167397
# instagram                                          Score: 10108.689745693684
# reddit                                             Score: 9366.602036995668
# gallery                                            Score: 9126.320481175027
# php                                                Score: 9047.541264576797
# gif                                                Score: 7416.849391430629
# co                                                 Score: 6989.149732236224
# media                                              Score: 6620.900272629394

# %%
# Load cosine_similarity function
from sklearn.metrics.pairwise import cosine_similarity

# Helper function
def print_top_n(result, df, top_n=5):
    top_n = 5
    sorted_result = result.argsort()[0][(-1*top_n):]
    list(reversed(sorted_result.tolist()))
    for idx in sorted_result:
        print("[{0}] : {1:.3f} : {2}".format(idx, result[0][idx], df.iloc[idx]['url']))

# %%
df[((df.label == 'malicious') & df.url.str.contains('paypal'))]['url'].head(5)
# Out:
# 950028    https://iad-login.dotomi.com/commonid/match?rurl=https%253A%252F%252Fadfarm....
# 950158           http://www.safetyking.ae/paypal/us-mmm/545fdad6a2d3ef280ded4edf8cbcd91c/
# 950286    http://theaccountidlimit.com/support-paypal-custmer-confirm-account-suspende...
# 950311    http://support.secure.paypal.com.services.d4a0v6qj59pi3.paripoorna.com/CA/1/...
# 950436    http://shinwoodnp.com/pod/asdr/www.paypal.de/cgi-bin/webscr/cmd=_login-run.p...
# Name: url, dtype: object

# %%
idx = 950311
result = cosine_similarity(features_transformed[idx:(idx+1)], features_transformed)
print_top_n(result, df)
# Out:
# [989802] : 0.617 : http://www.paypal.com.ca.services.ejlbv633r4yt.nadiastrologymumbai.com/CA/1/signn.php
# [998634] : 0.736 : http://customercare.secure.paypal.online.services.nvd8xjw.paripoorna.com/CA/1/signn.php?REDACTED
# [976859] : 0.839 : http://support.secure.paypal.online.services.j1avk9h.paripoorna.com/CA/1/signn.php
# [983475] : 0.872 : http://support.secure.paypal.com.services.g6nhzlipq9o.paripoorna.com/CA/1/signn.php
# [950311] : 1.000 : http://support.secure.paypal.com.services.d4a0v6qj59pi3.paripoorna.com/CA/1/signn.php

# %% [markdown]
# # Machine Learning with Naive Bayes

# %%
ml_dataset = df[940000:960000]
ml_dataset.label.value_counts()
# Out:
# malicious    10000
# benign       10000
# Name: label, dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB
# TF-IDF
vectorizer = TfidfVectorizer(max_df=.5)
X_data = vectorizer.fit_transform(ml_dataset.url)
vocab = vectorizer.vocabulary_

# Naive Bayes Classifier
cls = GaussianNB()
clf = cls.fit(X_data.toarray(), ml_dataset.label)

# %%
# malicious url
malicious_url = 'http://000webhostapp.php/wp-content/plugins/ubh/wells/gzjzty=/myaccount/emailaccess/login'
sample = pd.DataFrame([{'url' : malicious_url}])

vectorizer = TfidfVectorizer(vocabulary=vocab)
sample_tfidf = vectorizer.fit_transform(sample.url)
clf.predict(sample_tfidf.toarray())[0]
# Out:
# 'malicious'

# %%
# benign url
benign_url = 'https://www.youtube.com/watch?v=svlEfxTyJQE'
sample = pd.DataFrame([{'url': benign_url}])
sample_tfidf = vectorizer.fit_transform(sample.url)
clf.predict(sample_tfidf.toarray())[0]
# Out:
# 'benign'
